# %%
import pandas as pd

df = pd.read_csv("base_jogadores.csv", sep=";")
# Out:
# C:\Users\l5\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # Curiosidades

# %% [markdown]
# ### OverAll Médio = 66

# %%
media = df['overall'].median()
print(media)
# Out:
# 66.0

# %% [markdown]
# ### OverAll Moda = 65 (4307 repetições)

# %%
moda = df['overall'].mode()
print(moda)
# Out:
# 0    65
# dtype: int64

# %%
len(df['overall'][df['overall'] == 76])
# Out:
# 328

# %% [markdown]
# ### OverAll = 47 <> 93

# %%
min = df['overall'].min()
max = df['overall'].max()
print(min)
print(max)
# Out:
# 47
# 93

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Gráfico OverAll em linhas

# %%
plt.rcParams['figure.figsize'] = [20, 5]
plt.title("FIFA 22 - OverAll (Linha)")
plt.plot(df.overall)
plt.show()

# %% [markdown]
# ### Gráfico Idade em Linhas

# %%
plt.title("FIFA 22 - Idade (Linha)")
plt.plot(df.idade)
plt.show()

# %%
df.idade.max()
# Out:
# 54

# %%
temp = df.sort_values(by=['idade'], ascending=False)

# %% [markdown]
# ### Os 10 jogadores mais velhos

# %%
temp.head(10)
# Out:
#        Unnamed: 0      ID              nome           nome_completo  idade  \
# 16427       16427  254704          K. Miura         Kazuyoshi Miura     54
# 3673         3673  156483      C. Lucchetti      Cristian Lucchetti     43
# 13008       13008   29552       S. Nakamura       Shunsuke Nakamura     43
# 408           408    1179         G. Buffon        Gianluigi Buffon     43
# 11034       11034  209805           D. Vaca             Daniel Vaca     42
# 16759       16759    2702        K. Ellison           Kevin Ellison     42
# 5182         5182  105846          A. Boruc             Artur Boruc     41
# 17553       17553  102881  K. Stamatopoulos  Kyriakos Stamatopoulos     41
# 13341       13341  253638          J. Pinto              Joel Pinto     41
# 12589       12589  213483          S. Lukić            Stojan Lukić     41
#
#        peso  altura           nacionalidade  overall  potencial  ...  \
# 16427   177      72                   Japan       59         59  ...
# 3673    182      74               Argentina       72         72  ...
# 13008   178      71                   Japan       63         63  ...
# 408     192      92                   Italy       80         80  ...
# 11034   180      80                 Bolivia       65         65  ...
# 16759   185      76                 England       58         58  ...
# 5182    193      88                  Poland       70         70  ...
# 17553   188      80                  Canada       56         56  ...
# 13341   183      75                    Peru       63         63  ...
# 12589   192      91  Bosnia and Herzegovina       63         63  ...
#
#        penaltis  calma  marcacao combate carrinho GK_mergulho  GK_maos  \
# 16427        59     78        16      13       13           6       14
# 3673         54     41        21      22       13          73       70
# 13008        81     78        40      38       34           8        6
# 408          22     70        13      11       11          76       73
# 11034        20     34        23      19       17          59       62
# 16759        60     68        41      36       34           7       11
# 5182         21     63        15      20       20          71       65
# 17553        16     44        12       9       10          55       52
# 13341        13     28         7      13       15          62       65
# 12589        14     29        21      20       11          58       63
#
#        GK_chute  GK_posicionamento GK_reflexos
# 16427         8                  6           7
# 3673         77                 69          70
# 13008         7                 15           6
# 408          70                 90          76
# 11034        62                 71          63
# 16759         6                 14           6
# 5182         66                 70          71
# 17553        53                 54          55
# 13341        61                 60          63
# 12589        58                 67          63
#
# [10 rows x 70 columns]
