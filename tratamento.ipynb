# %%
import pandas as pd

df = pd.read_csv("players_fifa22.csv", sep=";")
# Out:
# C:\Users\l5\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (24) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # Tratamento de Dados

# %%
len(df.columns)
# Out:
# 69

# %%
df.dtypes
# Out:
# ID                int64
# Name             object
# FullName         object
# Age               int64
# Height            int64
#                   ...
# GKDiving          int64
# GKHandling        int64
# GKKicking         int64
# GKPositioning     int64
# GKReflexes        int64
# Length: 69, dtype: object

# %%
df.columns = ['ID', 'nome', 'nome_completo', 'idade', 'peso', 'altura', 'nacionalidade', 'overall', 'potencial', 'crescimento', 'total_stats', 'base_stats', 'posicoes', 'posicao_preferida', 'clube', 'valor_euro', 'salario_euro', 'passe_euro', 'posição_clube', 'fim_contrato', 'numero_camisa', 'entrou_no_clube', 'emprestimo', 'selecao', 'posicao_selecao', 'numero_selecao', 'pe', 'dedicacao_ataque', 'dedicacao_defesa', 'velocidade_total', 'chute_total', 'ultrapassagem_total', 'drible_total', 'defesa_total', 'fisico_total', 'cruzamento', 'finalizacao', 'cabeceio', 'passe_curto', 'voleio', 'firula', 'curva', 'falta', 'passe_longo', 'controle_bola', 'aceleracao', 'explosao', 'agilidade', 'reacao', 'equilibrio', 'forca_chute', 'pulo', 'stamina', 'forca', 'chute_longo', 'agressividade', 'interceptacao', 'posicionamento', 'visao_jogo', 'penaltis', 'calma', 'marcacao', 'combate', 'carrinho', 'GK_mergulho', 'GK_maos', 'GK_chute', 'GK_posicionamento', 'GK_reflexos']

# %%
df.head(10)
# Out:
#        ID               nome                 nome_completo  idade  peso  \
# 0  158023           L. Messi                  Lionel Messi     34   170
# 1  188545     R. Lewandowski            Robert Lewandowski     32   185
# 2  231747          K. Mbappé                 Kylian Mbappé     22   182
# 3  200389           J. Oblak                     Jan Oblak     28   188
# 4  192985       K. De Bruyne               Kevin De Bruyne     30   181
# 5  190871          Neymar Jr    Neymar da Silva Santos Jr.     29   175
# 6   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro     36   187
# 7  215914           N. Kanté                  N'Golo Kanté     30   168
# 8  202126            H. Kane                    Harry Kane     27   188
# 9  192448      M. ter Stegen         Marc-André ter Stegen     29   187
#
#    altura nacionalidade  overall  potencial  crescimento  ...  penaltis  \
# 0      72     Argentina       93         93            0  ...        75
# ...

# %%
df.columns
# Out:
# Index(['ID', 'nome', 'nome_completo', 'idade', 'peso', 'altura',
#        'nacionalidade', 'overall', 'potencial', 'crescimento', 'total_stats',
#        'base_stats', 'posicoes', 'posicao_preferida', 'clube', 'valor_euro',
#        'salario_euro', 'passe_euro', 'posição_clube', 'fim_contrato',
#        'numero_camisa', 'entrou_no_clube', 'emprestimo', 'selecao',
#        'posicao_selecao', 'numero_selecao', 'pe', 'dedicacao_ataque',
#        'dedicacao_defesa', 'velocidade_total', 'chute_total',
#        'ultrapassagem_total', 'drible_total', 'defesa_total', 'fisico_total',
#        'cruzamento', 'finalizacao', 'cabeceio', 'passe_curto', 'voleio',
#        'firula', 'curva', 'falta', 'passe_longo', 'controle_bola',
#        'aceleracao', 'explosao', 'agilidade', 'reacao', 'equilibrio',
#        'forca_chute', 'pulo', 'stamina', 'forca', 'chute_longo',
#        'agressividade', 'interceptacao', 'posicionamento', 'visao_jogo',
# ...

# %%
df['pe'][df['pe'] == 'Left'] = 'Esquerdo'
df['pe'][df['pe'] == 'Right'] = 'Direito'
# Out:
# <ipython-input-194-f7c5805d1bca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pe'][df['pe'] == 'Left'] = 'Esquerdo'
# <ipython-input-194-f7c5805d1bca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pe'][df['pe'] == 'Right'] = 'Direito'

# %%
df['dedicacao_ataque'][df['dedicacao_ataque'] == 'Low'] = 'Baixa'
df['dedicacao_defesa'][df['dedicacao_defesa'] == 'Low'] = 'Baixa'
df['dedicacao_ataque'][df['dedicacao_ataque'] == 'Medium'] = 'Média'
df['dedicacao_defesa'][df['dedicacao_defesa'] == 'Medium'] = 'Média'
df['dedicacao_ataque'][df['dedicacao_ataque'] == 'High'] = 'Alta'
df['dedicacao_defesa'][df['dedicacao_defesa'] == 'High'] = 'Alta'
# Out:
# <ipython-input-195-6160ddad0f4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dedicacao_ataque'][df['dedicacao_ataque'] == 'Low'] = 'Baixa'
# <ipython-input-195-6160ddad0f4a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dedicacao_defesa'][df['dedicacao_defesa'] == 'Low'] = 'Baixa'
# <ipython-input-195-6160ddad0f4a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df['selecao'][df['selecao'] == 'Not in team'] = 'Fora'
# Out:
# <ipython-input-196-cc676a1ae46c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['selecao'][df['selecao'] == 'Not in team'] = 'Fora'

# %%
df.head(10)
# Out:
#        ID               nome                 nome_completo  idade  peso  \
# 0  158023           L. Messi                  Lionel Messi     34   170
# 1  188545     R. Lewandowski            Robert Lewandowski     32   185
# 2  231747          K. Mbappé                 Kylian Mbappé     22   182
# 3  200389           J. Oblak                     Jan Oblak     28   188
# 4  192985       K. De Bruyne               Kevin De Bruyne     30   181
# 5  190871          Neymar Jr    Neymar da Silva Santos Jr.     29   175
# 6   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro     36   187
# 7  215914           N. Kanté                  N'Golo Kanté     30   168
# 8  202126            H. Kane                    Harry Kane     27   188
# 9  192448      M. ter Stegen         Marc-André ter Stegen     29   187
#
#    altura nacionalidade  overall  potencial  crescimento  ...  penaltis  \
# 0      72     Argentina       93         93            0  ...        75
# ...

# %%
df.to_csv('base_jogadores.csv', sep=';', encoding='utf-8-sig')
