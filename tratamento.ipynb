# %%
import pandas as pd

df = pd.read_csv("players_fifa22.csv", sep=";")
# Out:
# C:\Users\l5\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # Tratamento de Dados

# %%
len(df.columns)
# Out:
# 70

# %%
df.dtypes
# Out:
# ID                int64
# Name             object
# FullName         object
# Age               int64
# Height            int64
#                   ...
# GKDiving          int64
# GKHandling        int64
# GKKicking         int64
# GKPositioning     int64
# GKReflexes        int64
# Length: 70, dtype: object

# %%
df.columns = ['ID', 'nome', 'nome_completo', 'idade', 'peso', 'altura', 'photoURL', 'nacionalidade', 'overall', 'potencial', 'crescimento', 'total_stats', 'base_stats', 'posicoes', 'posicao_preferida', 'clube', 'valor_euro', 'salario_euro', 'passe_euro', 'posição_clube', 'fim_contrato', 'numero_camisa', 'entrou_no_clube', 'emprestimo', 'selecao', 'posicao_selecao', 'numero_selecao', 'pe', 'dedicacao_ataque', 'dedicacao_defesa', 'velocidade_total', 'chute_total', 'ultrapassagem_total', 'drible_total', 'defesa_total', 'fisico_total', 'cruzamento', 'finalizacao', 'cabeceio', 'passe_curto', 'voleio', 'firula', 'curva', 'falta', 'passe_longo', 'controle_bola', 'aceleracao', 'explosao', 'agilidade', 'reacao', 'equilibrio', 'forca_chute', 'pulo', 'stamina', 'forca', 'chute_longo', 'agressividade', 'interceptacao', 'posicionamento', 'visao_jogo', 'penaltis', 'calma', 'marcacao', 'combate', 'carrinho', 'GK_mergulho', 'GK_maos', 'GK_chute', 'GK_posicionamento', 'GK_reflexos']

# %%
df.head(10)
# Out:
#        ID               nome                 nome_completo  idade  peso  \
# 0  158023           L. Messi                  Lionel Messi     34   170
# 1  188545     R. Lewandowski            Robert Lewandowski     32   185
# 2  231747          K. Mbappé                 Kylian Mbappé     22   182
# 3  200389           J. Oblak                     Jan Oblak     28   188
# 4  192985       K. De Bruyne               Kevin De Bruyne     30   181
# 5  190871          Neymar Jr    Neymar da Silva Santos Jr.     29   175
# 6   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro     36   187
# 7  215914           N. Kanté                  N'Golo Kanté     30   168
# 8  202126            H. Kane                    Harry Kane     27   188
# 9  192448      M. ter Stegen         Marc-André ter Stegen     29   187
#
#    altura                                          photoURL nacionalidade  \
# 0      72  https://cdn.sofifa.com/players/158/023/22_60.png     Argentina
# 1      81  https://cdn.sofifa.com/players/188/545/22_60.png        Poland
# 2      73  https://cdn.sofifa.com/players/231/747/22_60.png        France
# 3      87  https://cdn.sofifa.com/players/200/389/22_60.png      Slovenia
# 4      70  https://cdn.sofifa.com/players/192/985/22_60.png       Belgium
# 5      68  https://cdn.sofifa.com/players/190/871/22_60.png        Brazil
# 6      83  https://cdn.sofifa.com/players/020/801/22_60.png      Portugal
# 7      70  https://cdn.sofifa.com/players/215/914/22_60.png        France
# 8      89  https://cdn.sofifa.com/players/202/126/22_60.png       England
# 9      85  https://cdn.sofifa.com/players/192/448/22_60.png       Germany
#
#    overall  potencial  ...  penaltis  calma  marcacao combate carrinho  \
# 0       93         93  ...        75     96        20      35       24
# 1       92         92  ...        90     88        35      42       19
# 2       91         95  ...        79     88        26      34       32
# 3       91         93  ...        11     68        27      12       18
# 4       91         91  ...        83     89        68      65       53
# 5       91         91  ...        93     93        35      32       29
# 6       91         91  ...        88     95        24      32       24
# 7       90         90  ...        54     84        90      93       86
# 8       90         90  ...        91     91        50      36       38
# 9       90         92  ...        25     70        25      13       10
#
#   GK_mergulho  GK_maos  GK_chute  GK_posicionamento GK_reflexos
# 0           6       11        15                 14           8
# 1          15        6        12                  8          10
# 2          13        5         7                 11           6
# 3          87       92        78                 90          90
# 4          15       13         5                 10          13
# 5           9        9        15                 15          11
# 6           7       11        15                 14          11
# 7          15       12        10                  7          10
# 8           8       10        11                 14          11
# 9          88       85        88                 88          90
#
# [10 rows x 70 columns]

# %%
df.columns
# Out:
# Index(['ID', 'nome', 'nome_completo', 'idade', 'peso', 'altura', 'photoURL',
#        'nacionalidade', 'overall', 'potencial', 'crescimento', 'total_stats',
#        'base_stats', 'posicoes', 'posicao_preferida', 'clube', 'valor_euro',
#        'salario_euro', 'passe_euro', 'posição_clube', 'fim_contrato',
#        'numero_camisa', 'entrou_no_clube', 'emprestimo', 'selecao',
#        'posicao_selecao', 'numero_selecao', 'pe', 'dedicacao_ataque',
#        'dedicacao_defesa', 'velocidade_total', 'chute_total',
#        'ultrapassagem_total', 'drible_total', 'defesa_total', 'fisico_total',
#        'cruzamento', 'finalizacao', 'cabeceio', 'passe_curto', 'voleio',
#        'firula', 'curva', 'falta', 'passe_longo', 'controle_bola',
#        'aceleracao', 'explosao', 'agilidade', 'reacao', 'equilibrio',
#        'forca_chute', 'pulo', 'stamina', 'forca', 'chute_longo',
#        'agressividade', 'interceptacao', 'posicionamento', 'visao_jogo',
#        'penaltis', 'calma', 'marcacao', 'combate', 'carrinho', 'GK_mergulho',
#        'GK_maos', 'GK_chute', 'GK_posicionamento', 'GK_reflexos'],
#       dtype='object')

# %%
df['pe'][df['pe'] == 'Left'] = 'Esquerdo'
df['pe'][df['pe'] == 'Right'] = 'Direito'
# Out:
# <ipython-input-169-f7c5805d1bca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pe'][df['pe'] == 'Left'] = 'Esquerdo'
# <ipython-input-169-f7c5805d1bca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pe'][df['pe'] == 'Right'] = 'Direito'

# %%
df['dedicacao_ataque'][df['dedicacao_ataque'] == 'Low'] = 'Baixa'
df['dedicacao_defesa'][df['dedicacao_defesa'] == 'Low'] = 'Baixa'
df['dedicacao_ataque'][df['dedicacao_ataque'] == 'Medium'] = 'Média'
df['dedicacao_defesa'][df['dedicacao_defesa'] == 'Medium'] = 'Média'
df['dedicacao_ataque'][df['dedicacao_ataque'] == 'High'] = 'Alta'
df['dedicacao_defesa'][df['dedicacao_defesa'] == 'High'] = 'Alta'
# Out:
# <ipython-input-170-6160ddad0f4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dedicacao_ataque'][df['dedicacao_ataque'] == 'Low'] = 'Baixa'
# <ipython-input-170-6160ddad0f4a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dedicacao_defesa'][df['dedicacao_defesa'] == 'Low'] = 'Baixa'
# <ipython-input-170-6160ddad0f4a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dedicacao_ataque'][df['dedicacao_ataque'] == 'Medium'] = 'Média'
# <ipython-input-170-6160ddad0f4a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dedicacao_defesa'][df['dedicacao_defesa'] == 'Medium'] = 'Média'
# <ipython-input-170-6160ddad0f4a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dedicacao_ataque'][df['dedicacao_ataque'] == 'High'] = 'Alta'
# <ipython-input-170-6160ddad0f4a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dedicacao_defesa'][df['dedicacao_defesa'] == 'High'] = 'Alta'

# %%
df.head(10)
# Out:
#        ID               Nome                 Nome Completo  Idade  Peso  \
# 0  158023           L. Messi                  Lionel Messi     34   170
# 1  188545     R. Lewandowski            Robert Lewandowski     32   185
# 2  231747          K. Mbappé                 Kylian Mbappé     22   182
# 3  200389           J. Oblak                     Jan Oblak     28   188
# 4  192985       K. De Bruyne               Kevin De Bruyne     30   181
# 5  190871          Neymar Jr    Neymar da Silva Santos Jr.     29   175
# 6   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro     36   187
# 7  215914           N. Kanté                  N'Golo Kanté     30   168
# 8  202126            H. Kane                    Harry Kane     27   188
# 9  192448      M. ter Stegen         Marc-André ter Stegen     29   187
#
#    Altura                                          PhotoURL Nacionalidade  \
# 0      72  https://cdn.sofifa.com/players/158/023/22_60.png     Argentina
# 1      81  https://cdn.sofifa.com/players/188/545/22_60.png        Poland
# 2      73  https://cdn.sofifa.com/players/231/747/22_60.png        France
# 3      87  https://cdn.sofifa.com/players/200/389/22_60.png      Slovenia
# 4      70  https://cdn.sofifa.com/players/192/985/22_60.png       Belgium
# 5      68  https://cdn.sofifa.com/players/190/871/22_60.png        Brazil
# 6      83  https://cdn.sofifa.com/players/020/801/22_60.png      Portugal
# 7      70  https://cdn.sofifa.com/players/215/914/22_60.png        France
# 8      89  https://cdn.sofifa.com/players/202/126/22_60.png       England
# 9      85  https://cdn.sofifa.com/players/192/448/22_60.png       Germany
#
#    OverAll  Potencial  ...  Pênaltis  Calma  Marcação Combate Carrinho  \
# 0       93         93  ...        75     96        20      35       24
# 1       92         92  ...        90     88        35      42       19
# 2       91         95  ...        79     88        26      34       32
# 3       91         93  ...        11     68        27      12       18
# 4       91         91  ...        83     89        68      65       53
# 5       91         91  ...        93     93        35      32       29
# 6       91         91  ...        88     95        24      32       24
# 7       90         90  ...        54     84        90      93       86
# 8       90         90  ...        91     91        50      36       38
# 9       90         92  ...        25     70        25      13       10
#
#   GK Mergulho  GK Mãos  GK Chute  GK Posicionamento GK Reflexos
# 0           6       11        15                 14           8
# 1          15        6        12                  8          10
# 2          13        5         7                 11           6
# 3          87       92        78                 90          90
# 4          15       13         5                 10          13
# 5           9        9        15                 15          11
# 6           7       11        15                 14          11
# 7          15       12        10                  7          10
# 8           8       10        11                 14          11
# 9          88       85        88                 88          90
#
# [10 rows x 70 columns]

# %%
df.to_csv('base_jogadores.csv', sep=';', encoding='utf-8-sig')
